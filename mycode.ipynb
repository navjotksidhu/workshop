# %%
print('hello world')
# Out:
# hello world

# %%
x=1.3;
int(x)
# Out:
# 1

# %%
a="aah, la'y chakk"
print(a)
# Out:
# aah, la'y chakk

# %%
a=5.3
b="aah, la'y chakk"
c=False
type(c)
# Out:
# bool

# %%
a="aah, la'y chakk"
a.upper()
# Out:
# "AAH, LA'Y CHAKK"

# %%
a[3]
# Out:
# ','

# %%
a[4:9] # list
# Out:
# " la'y"

# %%
len(a) #length of string a
# Out:
# 15

# %%
a.count('k') #counts the number of times you have a k in string a
# Out:
# 2

# %%
a.find("k") #finds the index of k in string a ie. the place from 0 to 14, where is your character in the string
# Out:
# 13

# %%
a.find("t")#returns -1 if the number is not present in string a
# Out:
# -1

# %%
print(a[0:3].find('h')) #find h from range 0 to 3
print(a[2:9].find("l")) #finds l from range 2 to 9
#if you dont put it in print, you will not get answer for both commands, see down
# Out:
# 2
# 3

# %%
a[0:3].find('h')
a[2:9].find("l") # without print you get solved the second one
# Out:
# 3

# %%
w=[1,2,4,7,"hello",8,True]
type(w)
# Out:
# list

# %%
type(w[6])#type of 6th element in list
# Out:
# bool

# %%
w[2:5] #print the elements from range 2 to 5
# Out:
# [4, 7, 'hello']

# %%
w[3:] #go till end if you leave the second element in range while defining the selection
# Out:
# [7, 'hello', 8, True]

# %%
w[:6] #go from 0 to 6 by default
# Out:
# [1, 2, 4, 7, 'hello', 8]

# %%
w[0:7:2] #print 0 to 7 by jump of 2
# Out:
# [1, 4, 'hello', True]

# %%
w[::3] #beginning to end jumping 3
# Out:
# [1, 7, True]

# %%
w[::-1] #reverses the list
# Out:
# [True, 8, 'hello', 7, 4, 2, 1]

# %%
a[::-1] #works on string as well
# Out:
# "kkahc y'al ,haa"

# %%
print(a[2::-1])
print(a)
# Out:
# haa
# aah, la'y chakk

# %%
print(w.index(True)) #problem here, true should be not at index 0
print(w)
# Out:
# 0
# [1, 2, 4, 7, 'hello', 8, True]

# %%
print(w.index("hello"))
print(w.index(4))
# Out:
# 4
# 2

# %%
lista="abcd" #if else and for

# %%
user_index=s.find(ineed)

# %%
if user_index!=-1:
    print(listb[user_index])
else:
    print("nf")
# Out:
# z

# %%
a=["fg", "hello", "3"]
for x in a:
    print(x)
    print("") #leaves 1 line
# Out:
# fg
#
# hello
#
# 3

# %%
s="abcd"

# %%
e="xywz"

# %%
user_list="ba"

# %%
for x in user_list:
    user_index=s.find(x)
    if user_index!=1:
        print(e[user_index])
    else:
        print("nf")
# Out:
# nf
# x

# %%
for x in user_list:
    user_index=s.find(x)
    if user_index!=-1:
        print(e[user_index])
    else:
        print("nf")
# Out:
# y
# x

# %%
e[1]+e[0]
# Out:
# 'yx'

# %%
for x in user_list:
    user_index=s.find(x)
    if user_index!=0:
        print(e[user_index])
    else:
        print("nf")
# Out:
# y
# nf

# %%
for x in user_list:
    user_index=s.find(x)
    if user_index not in [0,1]: #give range
        print(e[user_index])
    else:
        print("nf")
# Out:
# nf
# nf

# %%
"hello"+"world"
# Out:
# 'helloworld'

# %%
for x in user_list:
    user_index=s.find(x)
    if user_index!=-1:
        k=k+(e[user_index])
    else:
        print("nf")
print(k)
# Out:
# yxyx

# %%
def my_sum(s1, s2): #functions
    return(s1+s2)
my_sum("Hello","world")
# Out:
# 'Helloworld'

# %%
def my_sum(s1, s2):
    print("first string"+s1)
    print("second string"+s2)
    return(s1+s2)
my_sum("Hello","world")
# Out:
# first stringHello
# second stringworld
# 'Helloworld'

# %%
def my_sum(s1, s2):
    print (s1+s2)
    return
my_sum("Hello","world")
# Out:
# Helloworld

# %%
def my_sum(s1, s2):
    print (s1+s2)
    return
my_sum(1,2)
# Out:
# 3

# %%
def g_st(x,y):
    print(x**y)
    return
g_st(2,20)
# Out:
# 1048576

# %%
d = {'a':1,'b':2,'c':"hello",'marks':[1,2,3,4,5]} #dictionary

# %%
type(d["marks"])
# Out:
# list

# %%
for x in d:
    print(d[x])
# Out:
# 1
# 2
# hello
# [1, 2, 3, 4, 5]

# %%
type(d)
# Out:
# dict

# %%
import pandas #pandas datatype:series and dataframe

# %%
pandas.DataFrame({'a':[1,2],'b':[3,4]})
# Out:
#    a  b
# 0  1  3
# 1  2  4

# %%
df=pandas.DataFrame({'a':[1,2],'b':[3,4]})
len(df)
# Out:
# 2

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#import a panda as datafeame (up) import panda as pd(down)
import pandas as pd

# %%
df=pd.read_csv("physician_rx.csv") #importing file

# %%
len(df)
# Out:
# 100

# %%
df.head() #records from up the file
# Out:
#    PHYSICIAN  CroMax_RX  GlycoMax_RX  AllergyMax_RX  FevMax_RX  ColdMax_RX
# 0  AP1912920        0.0           50            510        152           0
# 1  AP1350415     2370.0         1320             60       1416        2676
# 2  AP0129322        0.0           85              0          0         144
# 3  AP0462902       30.0          570              0        128        3900
# 4  AP3185026        0.0           40           1080          0           0

# %%
df.tail() #show tail of file
# Out:
#     PHYSICIAN  CroMax_RX  GlycoMax_RX  AllergyMax_RX  FevMax_RX  ColdMax_RX
# 95  AP1957774      390.0           15              0         16          36
# 96  AP1273998      480.0          630              0          0           0
# 97  AP1228990        0.0            0              0          0         180
# 98  AP1881803        0.0           10              0          0           0
# 99  AP4772804       10.0            0              0          0           0

# %%
df.shape  # returns(rows,columns)
# Out:
# (100, 6)

# %%
df.columns
# Out:
# Index(['PHYSICIAN', 'CroMax_RX', 'GlycoMax_RX', 'AllergyMax_RX', 'FevMax_RX',
#        'ColdMax_RX'],
#       dtype='object')

# %%
#complete data table is taken by df
df
# Out:
#     PHYSICIAN  CroMax_RX  GlycoMax_RX  AllergyMax_RX  FevMax_RX  ColdMax_RX
# 0   AP1912920        0.0           50            510        152           0
# 1   AP1350415     2370.0         1320             60       1416        2676
# 2   AP0129322        0.0           85              0          0         144
# 3   AP0462902       30.0          570              0        128        3900
# 4   AP3185026        0.0           40           1080          0           0
# 5   AP3674571       70.0           40              0         64           0
# 6   AP0126982        0.0          135              0          0           0
# 7         NaN      150.0          315            270        184          36
# 8   AP1807651        0.0          650              0          0         300
# 9   AP0728371        0.0            0              0          0           0
# 10  AP1934892      640.0          390              0        280           0
# ...

# %%
df.dtypes #always check datatypes, shape etc before starting to work on the file
# Out:
# PHYSICIAN         object
# CroMax_RX        float64
# GlycoMax_RX        int64
# AllergyMax_RX      int64
# FevMax_RX          int64
# ColdMax_RX         int64
# dtype: object

# %%
#write df.(then press tab) to see every element/function possible on the dataframe

# %%
df["PHYSICIAN",]
# Out:
# 0     AP1912920
# 1     AP1350415
# 2     AP0129322
# 3     AP0462902
# 4     AP3185026
# 5     AP3674571
# 6     AP0126982
# 7           NaN
# 8     AP1807651
# 9     AP0728371
# 10    AP1934892
# 11    AP1595288
# 12    AP1883103
# 13    AP1365782
# 14          NaN
# 15    AP2443797
# 16    AP0036951
# 17    AP3200230
# 18    AP0139724
# 19    AP2166075
# 20          NaN
# 21    AP1332969
# 22    AP2130355
# 23    AP0714887
# 24    AP2214740
# 25    AP0857188
# 26          NaN
# 27    AP1874350
# 28    AP3209293
# 29    AP0089696
#         ...
# 70    AP0683877
# 71    AP0118925
# 72    AP2152296
# 73    AP1343639
# 74    AP1869077
# 75    AP2196115
# 76    AP1230067
# 77    AP2014650
# 78    AP2281620
# 79    AP1336198
# 80    AP0849708
# 81    AP2113896
# 82    AP1834639
# 83    AP0455565
# 84    AP0849030
# 85    AP0478796
# 86    AP3589376
# 87    AP2459335
# 88    AP0812453
# 89    AP0433841
# 90    AP1947403
# 91    AP0189854
# 92    AP3883979
# 93    AP0390218
# ...

# %%
df[["PHYSICIAN","AllergyMax_RX"]] #note that 2 parenthesis are used, 1st for syntex, 2nd for the list
# Out:
#     PHYSICIAN  AllergyMax_RX
# 0   AP1912920            510
# 1   AP1350415             60
# 2   AP0129322              0
# 3   AP0462902              0
# 4   AP3185026           1080
# 5   AP3674571              0
# 6   AP0126982              0
# 7         NaN            270
# 8   AP1807651              0
# 9   AP0728371              0
# 10  AP1934892              0
# 11  AP1595288             45
# 12  AP1883103            240
# 13  AP1365782            255
# 14        NaN              0
# 15  AP2443797              0
# 16  AP0036951              0
# 17  AP3200230              0
# 18  AP0139724            360
# 19  AP2166075              0
# 20        NaN              0
# 21  AP1332969              0
# 22  AP2130355              0
# 23  AP0714887            615
# 24  AP2214740              0
# 25  AP0857188              0
# 26        NaN            510
# 27  AP1874350             75
# 28  AP3209293            465
# 29  AP0089696           3435
# ..        ...            ...
# ...

# %%
df[["PHYSICIAN","AllergyMax_RX"]][2:9] #choose the rows you want
# Out:
#    PHYSICIAN  AllergyMax_RX
# 2  AP0129322              0
# 3  AP0462902              0
# 4  AP3185026           1080
# 5  AP3674571              0
# 6  AP0126982              0
# 7        NaN            270
# 8  AP1807651              0

# %%
df.loc[0:4,["PHYSICIAN","AllergyMax_RX"]] #use label names see the difference in syntex frm 180-184
# Out:
#    PHYSICIAN  AllergyMax_RX
# 0  AP1912920            510
# 1  AP1350415             60
# 2  AP0129322              0
# 3  AP0462902              0
# 4  AP3185026           1080

# %%
df.loc[0:4,"PHYSICIAN":"GlycoMax_RX"]
# Out:
#    PHYSICIAN  CroMax_RX  GlycoMax_RX
# 0  AP1912920        0.0           50
# 1  AP1350415     2370.0         1320
# 2  AP0129322        0.0           85
# 3  AP0462902       30.0          570
# 4  AP3185026        0.0           40

# %%
df.iloc[0:4,[0,3]] #use index names
# Out:
#    PHYSICIAN  AllergyMax_RX
# 0  AP1912920            510
# 1  AP1350415             60
# 2  AP0129322              0
# 3  AP0462902              0

# %%
df.iloc[0:4,0:3]
# Out:
#    PHYSICIAN  CroMax_RX  GlycoMax_RX
# 0  AP1912920        0.0           50
# 1  AP1350415     2370.0         1320
# 2  AP0129322        0.0           85
# 3  AP0462902       30.0          570

# %%
#boolean operations on file
df["CroMax_RX"]>50
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7      True
# 8     False
# 9     False
# 10     True
# 11     True
# 12    False
# 13     True
# 14     True
# 15    False
# 16     True
# 17    False
# 18    False
# 19    False
# 20    False
# 21     True
# 22     True
# 23     True
# 24    False
# 25    False
# 26     True
# 27    False
# 28    False
# 29     True
#       ...
# 70    False
# 71     True
# 72    False
# 73    False
# 74     True
# 75    False
# 76     True
# 77    False
# 78    False
# 79     True
# 80    False
# 81    False
# 82     True
# 83    False
# 84    False
# 85     True
# 86    False
# 87     True
# 88    False
# 89     True
# 90    False
# 91    False
# 92    False
# 93    False
# 94    False
# 95     True
# 96     True
# 97    False
# 98    False
# 99    False
# Name: CroMax_RX, Length: 100, dtype: bool

# %%
df[df["CroMax_RX"]>50] #give the whole data in the rows which has cromax_rx>50
# Out:
#     PHYSICIAN  CroMax_RX  GlycoMax_RX  AllergyMax_RX  FevMax_RX  ColdMax_RX
# 1   AP1350415     2370.0         1320             60       1416        2676
# 5   AP3674571       70.0           40              0         64           0
# 7         NaN      150.0          315            270        184          36
# 10  AP1934892      640.0          390              0        280           0
# 11  AP1595288      160.0           35             45          0           0
# 13  AP1365782      400.0           15            255        704         444
# 14        NaN       90.0          150              0          0         204
# 16  AP0036951      330.0          525              0          0           0
# 21  AP1332969       90.0          870              0         88          24
# 22  AP2130355      160.0          145              0          0         180
# 23  AP0714887      160.0          780            615         16        2964
# ...

# %%
df1=df[(df["CroMax_RX"]>50)]
df1
# Out:
#     PHYSICIAN  CroMax_RX  GlycoMax_RX  AllergyMax_RX  FevMax_RX  ColdMax_RX
# 1   AP1350415     2370.0         1320             60       1416        2676
# 5   AP3674571       70.0           40              0         64           0
# 7         NaN      150.0          315            270        184          36
# 10  AP1934892      640.0          390              0        280           0
# 11  AP1595288      160.0           35             45          0           0
# 13  AP1365782      400.0           15            255        704         444
# 14        NaN       90.0          150              0          0         204
# 16  AP0036951      330.0          525              0          0           0
# 21  AP1332969       90.0          870              0         88          24
# 22  AP2130355      160.0          145              0          0         180
# 23  AP0714887      160.0          780            615         16        2964
# ...

# %%
df2=df1[(df1["GlycoMax_RX"]>50)]
df2
# Out:
#     PHYSICIAN  CroMax_RX  GlycoMax_RX  AllergyMax_RX  FevMax_RX  ColdMax_RX
# 1   AP1350415     2370.0         1320             60       1416        2676
# 7         NaN      150.0          315            270        184          36
# 10  AP1934892      640.0          390              0        280           0
# 14        NaN       90.0          150              0          0         204
# 16  AP0036951      330.0          525              0          0           0
# 21  AP1332969       90.0          870              0         88          24
# 22  AP2130355      160.0          145              0          0         180
# 23  AP0714887      160.0          780            615         16        2964
# 26        NaN      150.0          220            510         32        1128
# 29  AP0089696      930.0          250           3435          0         396
# 31  AP0692473       90.0          215            375          0         348
# ...

# %%
df[(df["CroMax_RX"]>50)&(df["FevMax_RX"]>50)] #both are >50
# Out:
#     PHYSICIAN  CroMax_RX  GlycoMax_RX  AllergyMax_RX  FevMax_RX  ColdMax_RX
# 1   AP1350415     2370.0         1320             60       1416        2676
# 5   AP3674571       70.0           40              0         64           0
# 7         NaN      150.0          315            270        184          36
# 10  AP1934892      640.0          390              0        280           0
# 13  AP1365782      400.0           15            255        704         444
# 21  AP1332969       90.0          870              0         88          24
# 42  AP1326350       80.0          250            690        128          48
# 53  AP1976314      170.0          495              0        200          24
# 71  AP0118925      160.0          375              0        240           0
# 74  AP1869077     1830.0          140              0        488          72
# 87  AP2459335      320.0          320              0        256          12

# %%
df.iloc[0:1,0:1]
# Out:
#    PHYSICIAN
# 0  AP1912920

# %%
#iat and at return a single cell too
df.iat[0,0]
# Out:
# 'AP1912920'

# %%
df.at[0,"PHYSICIAN"]
# Out:
# 'AP1912920'

# %%
#isnull gives missing values
df.isnull()
# Out:
#     PHYSICIAN  CroMax_RX  GlycoMax_RX  AllergyMax_RX  FevMax_RX  ColdMax_RX
# 0       False      False        False          False      False       False
# 1       False      False        False          False      False       False
# 2       False      False        False          False      False       False
# 3       False      False        False          False      False       False
# 4       False      False        False          False      False       False
# 5       False      False        False          False      False       False
# 6       False      False        False          False      False       False
# 7        True      False        False          False      False       False
# 8       False      False        False          False      False       False
# 9       False      False        False          False      False       False
# 10      False      False        False          False      False       False
# ...

# %%
df.isnull().sum()
# Out:
# PHYSICIAN        4
# CroMax_RX        4
# GlycoMax_RX      0
# AllergyMax_RX    0
# FevMax_RX        0
# ColdMax_RX       0
# dtype: int64

# %%
df[df["CroMax_RX"].isnull()]
# Out:
#     PHYSICIAN  CroMax_RX  GlycoMax_RX  AllergyMax_RX  FevMax_RX  ColdMax_RX
# 33  AP0464297        NaN          405              0          0          36
# 48  AP1948690        NaN          105            690          8           0
# 65  AP2102094        NaN          220              0        432         216
# 88  AP0812453        NaN           45              0          0         264

# %%
df["CroMax_RX"]=df["CroMax_RX"].fillna(0)

# %%
df.isnull().sum()
# Out:
# PHYSICIAN        4
# CroMax_RX        0
# GlycoMax_RX      0
# AllergyMax_RX    0
# FevMax_RX        0
# ColdMax_RX       0
# dtype: int64

# %%
df=df.dropna() #drops all na values

# %%
df.isnull().sum()
# Out:
# PHYSICIAN        0
# CroMax_RX        0
# GlycoMax_RX      0
# AllergyMax_RX    0
# FevMax_RX        0
# ColdMax_RX       0
# dtype: int64

# %%
df.columns
# Out:
# Index(['PHYSICIAN', 'CroMax_RX', 'GlycoMax_RX', 'AllergyMax_RX', 'FevMax_RX',
#        'ColdMax_RX'],
#       dtype='object')

# %%
df.columns=['PHY', 'CroMax_RX', 'GlycoMax_RX', 'AllergyMax_RX', 'FevMax_RX',
       'ColdMax_RX']

# %%
df.head()
# Out:
#          PHY  CroMax_RX  GlycoMax_RX  AllergyMax_RX  FevMax_RX  ColdMax_RX
# 0  AP1912920        0.0           50            510        152           0
# 1  AP1350415     2370.0         1320             60       1416        2676
# 2  AP0129322        0.0           85              0          0         144
# 3  AP0462902       30.0          570              0        128        3900
# 4  AP3185026        0.0           40           1080          0           0

# %%
#alternate way define new dictionary
df=df.rename(columns={'PHY':'physician'})

# %%
df.head()
# Out:
#    physician  CroMax_RX  GlycoMax_RX  AllergyMax_RX  FevMax_RX  ColdMax_RX
# 0  AP1912920        0.0           50            510        152           0
# 1  AP1350415     2370.0         1320             60       1416        2676
# 2  AP0129322        0.0           85              0          0         144
# 3  AP0462902       30.0          570              0        128        3900
# 4  AP3185026        0.0           40           1080          0           0

# %%
#pattern based replacements, replace all underscores by dot
df.columns
# Out:
# Index(['physician', 'CroMax_RX', 'GlycoMax_RX', 'AllergyMax_RX', 'FevMax_RX',
#        'ColdMax_RX'],
#       dtype='object')

# %%
df.columns=df.columns.str.replace("_",".")
df.columns
# Out:
# Index(['physician', 'CroMax.RX', 'GlycoMax.RX', 'AllergyMax.RX', 'FevMax.RX',
#        'ColdMax.RX'],
#       dtype='object')

# %%
#replace AP in PHY id by AB
df["physician"]=df["physician"].str.replace("AP","AB")
print(df.head())
print(df.tail())
# Out:
#    physician  CroMax.RX  GlycoMax.RX  AllergyMax.RX  FevMax.RX  ColdMax.RX
# 0  AB1912920        0.0           50            510        152           0
# 1  AB1350415     2370.0         1320             60       1416        2676
# 2  AB0129322        0.0           85              0          0         144
# 3  AB0462902       30.0          570              0        128        3900
# 4  AB3185026        0.0           40           1080          0           0
#     physician  CroMax.RX  GlycoMax.RX  AllergyMax.RX  FevMax.RX  ColdMax.RX
# 95  AB1957774      390.0           15              0         16          36
# 96  AB1273998      480.0          630              0          0           0
# 97  AB1228990        0.0            0              0          0         180
# 98  AB1881803        0.0           10              0          0           0
# 99  AB4772804       10.0            0              0          0           0

# %%
#add a column
df["bucket"]="B2"
df.head()
# Out:
#    physician  CroMax.RX  GlycoMax.RX  AllergyMax.RX  FevMax.RX  ColdMax.RX  \
# 0  AB1912920        0.0           50            510        152           0
# 1  AB1350415     2370.0         1320             60       1416        2676
# 2  AB0129322        0.0           85              0          0         144
# 3  AB0462902       30.0          570              0        128        3900
# 4  AB3185026        0.0           40           1080          0           0
#
#   bucket
# 0     B2
# 1     B2
# 2     B2
# 3     B2
# 4     B2

# %%
df.loc[(df["CroMax.RX"]>50)&(df["FevMax.RX"]>50), "bucket"]="B1" #change B2 by B1 if 
df.head()
# Out:
#    physician  CroMax.RX  GlycoMax.RX  AllergyMax.RX  FevMax.RX  ColdMax.RX  \
# 0  AB1912920        0.0           50            510        152           0
# 1  AB1350415     2370.0         1320             60       1416        2676
# 2  AB0129322        0.0           85              0          0         144
# 3  AB0462902       30.0          570              0        128        3900
# 4  AB3185026        0.0           40           1080          0           0
#
#   bucket
# 0     B2
# 1     B1
# 2     B2
# 3     B2
# 4     B2

# %%
df["newphysician"]=df["bucket"]+df["physician"]
df.head()
# Out:
#    physician  CroMax.RX  GlycoMax.RX  AllergyMax.RX  FevMax.RX  ColdMax.RX  \
# 0  AB1912920        0.0           50            510        152           0
# 1  AB1350415     2370.0         1320             60       1416        2676
# 2  AB0129322        0.0           85              0          0         144
# 3  AB0462902       30.0          570              0        128        3900
# 4  AB3185026        0.0           40           1080          0           0
#
#   bucket newphysician
# 0     B2  B2AB1912920
# 1     B1  B1AB1350415
# 2     B2  B2AB0129322
# 3     B2  B2AB0462902
# 4     B2  B2AB3185026

# %%
df.head()
# Out:
#    physician  CroMax.RX  GlycoMax.RX  AllergyMax.RX  FevMax.RX  ColdMax.RX  \
# 0  AB1912920        0.0           50            510        152           0
# 1  AB1350415     2370.0         1320             60       1416        2676
# 2  AB0129322        0.0           85              0          0         144
# 3  AB0462902       30.0          570              0        128        3900
# 4  AB3185026        0.0           40           1080          0           0
#
#   bucket     physician
# 0     B2  B2_AB1912920
# 1     B1  B1_AB1350415
# 2     B2  B2_AB0129322
# 3     B2  B2_AB0462902
# 4     B2  B2_AB3185026

# %%
df = df.iloc[:,0:-1 ]

# %%
df.columns
# Out:
# Index(['physician', 'CroMax.RX', 'GlycoMax.RX', 'AllergyMax.RX', 'FevMax.RX',
#        'ColdMax.RX', 'bucket', 'newphysician'],
#       dtype='object')

# %%
df=df[['newphysician', 'CroMax.RX', 'GlycoMax.RX', 'AllergyMax.RX', 'FevMax.RX',
       'ColdMax.RX', 'bucket']]
df.head()
# Out:
#   newphysician  CroMax.RX  GlycoMax.RX  AllergyMax.RX  FevMax.RX  ColdMax.RX  \
# 0  B2AB1912920        0.0           50            510        152           0
# 1  B1AB1350415     2370.0         1320             60       1416        2676
# 2  B2AB0129322        0.0           85              0          0         144
# 3  B2AB0462902       30.0          570              0        128        3900
# 4  B2AB3185026        0.0           40           1080          0           0
#
#   bucket
# 0     B2
# 1     B1
# 2     B2
# 3     B2
# 4     B2

# %%
#splitt the string
"hello_world".spli
